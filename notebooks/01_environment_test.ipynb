# %%
import sys
import pandas as pd
import numpy as np
import matplotlib
import pypdf
import streamlit
import openai
import quantmind

print("Python:", sys.version)
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
print("QuantMind: imported successfully")
# Out:
# Python: 3.11.16 | packaged by Anaconda, Inc. | (main, Aug 27 2026, 14:36:16) [MSC v.1942 64 bit (AMD64)]
# Pandas: 3.0.5
# NumPy: 2.4.6
# QuantMind: imported successfully
